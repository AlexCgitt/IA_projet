# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import GridSearchCV
from time import time
import joblib

# %%
# Chargement des données
DataFrame = pd.read_csv("Data_Arbre.csv")



# Préparation des données
DataFrame.loc[DataFrame['fk_arb_etat'] == 'Essouché', 'fk_arb_etat'] = 1
DataFrame.loc[DataFrame['fk_arb_etat'] != 1, 'fk_arb_etat'] = 0
DataFrame['fk_arb_etat'] = DataFrame['fk_arb_etat'].astype('int')

# Sélectionner les colonnes pertinentes
colonnes_numeriques = ['longitude', 'latitude', 'haut_tot', 'haut_tronc', 'tronc_diam', 'age_estim', 'fk_prec_estim', 'clc_nbr_diag']
colonnes_categorieles = ['clc_quartier', 'clc_secteur', 'fk_stadedev', 'fk_port', 'fk_pied', 'fk_situation', 'fk_revetement', 'fk_nomtech', 'feuillage', 'villeca']
DataFrame.loc[DataFrame['remarquable'] == 'Oui', 'remarquable'] = 1
DataFrame.loc[DataFrame['remarquable'] != 1, 'remarquable'] = 0
DataFrame['remarquable'] = DataFrame['remarquable'].astype('int')

# %%
# Encodage des variables catégorielles
X = pd.concat([DataFrame[colonnes_numeriques], pd.get_dummies(DataFrame[colonnes_categorieles]), DataFrame['remarquable']], axis=1)
y = DataFrame['fk_arb_etat']

# Standardisation des données
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# Sauvegarder le scaler
# 2 possibilités pour sauvegarder un modèle : joblib et pickle allez voir les doc pour plus d'infos
# joblib est plus rapide et plus efficace pour les gros modèles
# joblib est plus adapté pour les objets sklearn
joblib.dump(scaler, 'scaler.pkl')

# Diviser les données en ensemble d'entraînement et de test
indices = np.arange(X.shape[0])
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X_scaled, y, indices, test_size=0.3, random_state=42)

data_test_csv = pd.read_csv("Data_Arbre.csv")
data_test = data_test_csv.iloc[indices_test]

data_test.to_json('data_test.json', orient='records')
# Out:
# [[ 0.42896038  1.37374021  1.02314578 ... -0.30669821  0.30669821
#   -0.12105172]
#  [-1.47150196 -0.34763432 -0.59694528 ... -0.30669821  0.30669821
#   -0.12105172]
#  [ 0.97441487  0.35896618  0.53711846 ... -0.30669821  0.30669821
#   -0.12105172]
#  ...
#  [ 0.31151847 -1.33289973 -0.43493618 ... -0.30669821  0.30669821
#   -0.12105172]
#  [ 0.8063264   0.44500884 -1.0829726  ... -0.30669821  0.30669821
#   -0.12105172]
#  [ 0.64291388 -0.78951003 -0.27292707 ...  3.26053419 -3.26053419
#   -0.12105172]]

# %%
# Appliquer SMOTE sur l'ensemble d'entraînement uniquement
smote = SMOTE(random_state=42, sampling_strategy=0.2)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

param_grid = {
    #pour savoir quels paramètre mettre dans param_grid, on peut faire une recherche sur Randomforestclassifier sur la doc de sklearn https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html et voir les paramètres qu'on peut mettre
    'n_estimators': [ 70, 80, 90],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    #'bootstrap': [True, False],
    #'max_features': ['auto', 'sqrt', 'log2']
}

# Configurer GridSearchCV
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV.get_params
# n_jobs = -1 pour utiliser tous les coeurs du processeur
# verbose = 2 pour afficher les logs
# on aurait pu ajouter  refit=True pour entrainer le modèle avec les meilleurs hyperparamètres trouvés
clf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# Exécuter GridSearchCV
grid_search.fit(X_train_smote, y_train_smote)

# Obtenir les meilleurs hyperparamètres
best_params = grid_search.best_params_
print("Meilleurs hyperparamètres trouvés : ", best_params)

# Entraîner le modèle avec les meilleurs hyperparamètres

best_clf = grid_search.best_estimator_

# Sauvegarder le meilleur modèle
joblib.dump(best_clf, 'best_random_forest_model.pkl')

# Importance des caractéristiques
importance = best_clf.feature_importances_
indices = np.argsort(importance)[::-1]
print("\nImportance des caractéristiques :")
for f in range(X_train_smote.shape[1]):
    print(f"{X.columns[indices[f]]} : {importance[indices[f]]}")
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# Meilleurs hyperparamètres trouvés :  {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 80}
#
# Importance des caractéristiques :
# haut_tronc : 0.07548235321308842
# fk_prec_estim : 0.06305520022143106
# longitude : 0.06080154344943156
# clc_nbr_diag : 0.05842746294415226
# age_estim : 0.05731531343023211
# latitude : 0.054506211299073994
# clc_secteur_Parc des Champs-Elysées : 0.04176904131387971
# haut_tot : 0.039484129415935806
# tronc_diam : 0.03691148116423884
# fk_situation_Groupe : 0.03029006576529309
# fk_situation_Alignement : 0.027067101954085005
# fk_nomtech_SORAUC : 0.025366172555163748
# clc_secteur_Cimetière Sud : 0.020294575801554603
# fk_pied_gazon : 0.019657012539156617
# clc_quartier_Quartier Remicourt : 0.019262967271591123
# fk_situation_Isolé : 0.015196520260346708
# fk_nomtech_BETPEN : 0.014701996969934645
# clc_quartier_Quartier du faubourg d'Isle : 0.013305851509372451
# villeca_VILLE : 0.011926144092771233
# clc_secteur_Auberge de jeunesse : 0.011848436008064308
# fk_port_semi libre : 0.01141359551293854
# villeca_CASQ : 0.011227434626661117
# fk_pied_Terre : 0.010953722051355872
# clc_quartier_Quartier de l'Europe : 0.009541256688530895
# fk_nomtech_ACEPSE : 0.009422532391166718
# fk_stadedev_Jeune : 0.009348071740745851
# fk_nomtech_ACEPLA : 0.009289231626059635
# fk_stadedev_Adulte : 0.009266276096622067
# feuillage_Conifère : 0.009256830203394227
# clc_secteur_Parc d'Isle Jacques Braconnier : 0.009147512763311747
# fk_nomtech_ACESAC : 0.00814753109345313
# feuillage_Feuillu : 0.007324585817278783
# fk_nomtech_TILCOR : 0.007319219168685621
# clc_secteur_Rue d'Alembert : 0.006831531571995546
# fk_nomtech_PINNIGnig : 0.00611510069797286
# clc_secteur_Rue François Mitterrand : 0.005779134820580595
# clc_secteur_Square des Marronniers : 0.005676168114689866
# fk_nomtech_POPNIGita : 0.005390326427872504
# clc_secteur_Stade Gaston Massot : 0.004876687414955909
# fk_nomtech_SALBAB : 0.004821902453132328
# remarquable : 0.004776789781327453
# fk_nomtech_CUPLEY : 0.004495571919879596
# fk_nomtech_PLAACE : 0.004433487869812497
# clc_secteur_Square Churchill : 0.004190269867669705
# fk_port_Libre : 0.004107041515557592
# clc_secteur_Espace Henry Dunant : 0.003902273987614502
# fk_nomtech_POPCAN : 0.0038715213670411823
# clc_secteur_Groupe scolaire Ferdinand Buisson : 0.00346838478676356
# fk_nomtech_ACECAM : 0.0032952455392353023
# fk_nomtech_CATBIG : 0.003179756275737795
# clc_quartier_Quartier Saint-Martin - Oëstres : 0.0030624898089921864
# fk_nomtech_POPNIG : 0.003033190635169801
# clc_secteur_Place du Nain d'Alsace : 0.003009258877777442
# fk_port_réduit relâché : 0.0025022776054660044
# fk_nomtech_AESHIP : 0.002435000298659467
# clc_quartier_OMISSY : 0.002403517291432832
# fk_pied_fosse arbre : 0.0023065611958906656
# fk_revetement_Oui : 0.0022604795663786876
# clc_secteur_Rue Boileau : 0.00217039336886348
# clc_quartier_HARLY : 0.0021580272914180194
# fk_revetement_Non : 0.002102636444491687
# clc_quartier_Quartier de Neuville : 0.002066805357540035
# clc_quartier_Quartier du Centre-Ville : 0.0020017683007762035
# clc_quartier_Quartier Saint-Jean : 0.0019774414929902176
# fk_nomtech_LIQSTY : 0.00181681722507261
# clc_secteur_Terrain aventure Neuville : 0.0017988728044697657
# fk_port_architecturé : 0.0017709556086353557
# clc_secteur_Gymnase Eugène Corette : 0.0017245571335958959
# clc_secteur_Stade Marcel Bienfait : 0.0017194858237431034
# fk_stadedev_senescent : 0.0016916785896868257
# clc_quartier_Quartier du Vermandois : 0.001645393236413124
# clc_secteur_Rue Gay Lussac : 0.00161710133489259
# fk_pied_Revetement non permeable : 0.0015965411855687166
# fk_nomtech_PRUSER : 0.001590587558810903
# fk_nomtech_PAUTOM : 0.0015734479838025728
# fk_port_tête de chat : 0.0015241886345821907
# clc_secteur_Gymnase Pierre Laroche : 0.001490721223866211
# clc_secteur_Ecole primaire Pierre Laroche : 0.0014439364934977622
# fk_nomtech_AESCAR : 0.001399231641636311
# fk_nomtech_ACECAMros : 0.0012098956931951798
# fk_nomtech_ACEPLAcri : 0.0011914971699116183
# clc_secteur_Terrain aventure Europe : 0.001184231077165827
# clc_secteur_Avenue Robert Schuman : 0.0011797221305944823
# fk_nomtech_PRUCERpis : 0.0011630406355426256
# clc_secteur_Groupe scolaire Jacques Prévert : 0.001073922484229858
# fk_nomtech_ACESACwie : 0.0010726893556983626
# clc_secteur_Bibliothèque Guy de Maupassant : 0.0009735386868109366
# fk_port_Semi libre : 0.0009697225337646513
# fk_port_réduit : 0.0009048548853624787
# fk_nomtech_FAGSYL : 0.0008655591400049435
# fk_nomtech_POPALB : 0.0008448864009672228
# clc_secteur_Boulevard Cordier : 0.0008192149121354743
# clc_secteur_Rue Louis Galvani : 0.0007738627963706933
# clc_secteur_Square Albert Thomas : 0.0007647427288518636
# clc_secteur_Rue Geoffroy Saint-Hilaire : 0.0007458718332715007
# clc_secteur_Avenue des Fusillés de Fontaine Notre Dame : 0.0007407332334081946
# clc_secteur_Avenue Buffon : 0.0007335826065251632
# clc_secteur_Groupe Scolaire Georges Bachy : 0.000720759307590223
# fk_nomtech_AEShom : 0.0007143883942766744
# fk_nomtech_LIRTUL : 0.0006778921642834016
# clc_secteur_Rue Marconi : 0.0006345699114470873
# fk_nomtech_FAGSYLpur : 0.0006291827953282272
# clc_secteur_Rue Gustave Eiffel : 0.0005884988424779941
# clc_secteur_Gymnase LEP : 0.0005648851812519212
# clc_secteur_Rue Hertz : 0.0005572128881679378
# clc_secteur_Rue des Jacobins : 0.0005337037249111196
# clc_secteur_Rue Alexandre Dumas : 0.0005333218905657743
# fk_nomtech_MAL : 0.0005328513287231918
# fk_nomtech_CUP : 0.0005176121406617695
# fk_nomtech_CRALAEpau : 0.0005135610343853476
# clc_secteur_Square Saint Jean : 0.0005071930503174036
# clc_secteur_Rue du Colonel Driant : 0.0004930437548790125
# fk_nomtech_POPTRE : 0.0004737503161953801
# clc_secteur_Ecole élémentaire Ernest Lavisse : 0.0004601866211734158
# fk_nomtech_TILTOM : 0.0004538965308338255
# fk_nomtech_ROBPSE : 0.000443197817338833
# clc_secteur_Square Romain Tricoteaux : 0.0004357954361942335
# clc_secteur_Parking Arthur Gibert : 0.00043195890358385745
# clc_secteur_Avenue de la Résistance : 0.0004265121314225084
# fk_nomtech_PRUSERkan : 0.0004190495292598948
# clc_secteur_Rue Berthollet : 0.00041198827127980836
# clc_secteur_Résidence Charleroi : 0.00041007918312074983
# fk_nomtech_PYRCAL : 0.00040710835498345717
# fk_stadedev_vieux : 0.00040368536236110345
# clc_secteur_Boulevard Roosevelt : 0.0004024546847466102
# clc_secteur_Entrée du Centre Hospitalier : 0.00039668090773362276
# clc_secteur_Rue des Frères Lumière : 0.0003926105128817894
# clc_secteur_Rue Jean Mermoz : 0.0003801344926396105
# fk_port_cépée : 0.00034026836092929916
# clc_secteur_Espace Matisse : 0.000339634270797123
# clc_secteur_Rue Salvador Allende : 0.00031839618136233534
# clc_secteur_Avenue Charles Feuillette : 0.00031602314366276606
# fk_nomtech_POPSIM : 0.00031570704057362045
# clc_secteur_Jardin d'horticulture : 0.00031065329456049577
# clc_secteur_Rue du Capitaine Dumont : 0.00027870099365374284
# fk_nomtech_CARBET : 0.00027572330129522295
# clc_secteur_Piscine Jean Bouin : 0.00027288128403761005
# clc_secteur_Ecole élémentaire Eugène Corette : 0.0002721003399199174
# fk_nomtech_PICABI : 0.0002668764209314221
# clc_secteur_Rue Henri Barbusse : 0.00024359030394120485
# clc_secteur_Stade Paul Debrésie : 0.0002166317211026463
# clc_secteur_Rue de Lille : 0.00021222064210361393
# clc_secteur_Rue Jean Cocteau : 0.00020875279034332565
# fk_nomtech_FRAEXC : 0.0002004747688259356
# clc_secteur_Rue Fleming : 0.0001981327444473948
# clc_secteur_Espace de glisse : 0.00018559954912353172
# fk_nomtech_SOPJAP : 0.000178305602674456
# clc_secteur_Rue Jacky Tabar : 0.00016690751061095274
# clc_secteur_Stade municipal plein air : 0.00015179597099748932
# clc_secteur_Rue de Paris : 0.0001487351721505327
# fk_port_tête de chat relaché : 0.0001392932648575028
# fk_nomtech_PYRCALcha : 0.00013613198381287847
# clc_secteur_Avenue Pierre Chocquart : 0.0001301630649099351
# fk_nomtech_CARBETfas : 0.0001297738995765297
# clc_secteur_Place de la Libération : 0.00012659795751232246
# clc_secteur_Boulevard du Docteur Camille Guérin : 0.00012544819941433244
# clc_secteur_Ecole primaire François Collery : 0.0001240290124586765
# fk_nomtech_CEDATL : 0.00012294411507170872
# fk_nomtech_SALALB : 0.00012117450803144942
# clc_secteur_Square André Malraux : 0.0001193932008381396
# fk_nomtech_ACENEG : 0.00011740951368120514
# clc_secteur_Rue Laplace : 0.00011721143942113008
# clc_secteur_Ecole maternelle Benjamin Rouché : 0.00011512468324182627
# fk_nomtech_THUPLIatr : 0.00011211826153391632
# clc_secteur_Parvis Stade Paul Debrésie : 0.00011167457186743691
# clc_secteur_Parvis Gare : 0.00010367192018538169
# clc_secteur_Ecole primaire Henri Arnould : 0.00010315087757233354
# clc_secteur_Place Stalingrad : 0.00010035480773853481
# clc_secteur_Route d'Amiens : 0.0001001730516505323
# clc_secteur_Ecole maternelle Pierre Laroche : 9.990048726895326e-05
# clc_secteur_Ecole maternelle Maria Montessori : 9.103061158803835e-05
# clc_secteur_Gymnase François Collery : 9.0282906071112e-05
# clc_secteur_Boulevard Jean Bouin : 8.977937577400509e-05
# clc_secteur_Chemin de Morcourt : 8.661253862204946e-05
# clc_secteur_Ecole primaire Paul Bert : 8.380952179051945e-05
# fk_nomtech_THUPLI : 8.055531768597429e-05
# clc_secteur_Square Marché Franc : 7.961092401062383e-05
# clc_secteur_Ecole maternelle Paul Bert : 7.693582402218867e-05
# clc_secteur_Rue Jean Falloux : 7.573440937666743e-05
# fk_nomtech_TAXBAC : 7.538688792540628e-05
# clc_secteur_Rue de la Fere : 7.327848471519254e-05
# fk_nomtech_CUPARIgla : 7.324380813667949e-05
# fk_nomtech_CASSAT : 7.081617967613297e-05
# clc_secteur_Rue du Président John Fitzgerald Kennedy : 6.984876372109488e-05
# fk_nomtech_JUGREG : 6.85653793371551e-05
# clc_secteur_Terrain de mini golf : 6.823605650645943e-05
# fk_nomtech_FRAORN : 6.612132659800018e-05
# clc_secteur_Rue de Baudreuil : 6.52647460686892e-05
# clc_secteur_CCAS : 6.520841309584027e-05
# clc_secteur_Chemin Saint Laurent : 6.086571225791738e-05
# fk_nomtech_LABANA : 5.942248886064742e-05
# fk_nomtech_SEQGIG : 5.428882687997234e-05
# fk_nomtech_GINBIL : 5.411848048622225e-05
# fk_nomtech_CORCOL : 5.362846250380879e-05
# clc_secteur_Rue de la Fère : 5.223591140852186e-05
# fk_port_Couronne : 5.0182992390973144e-05
# fk_nomtech_FRAANGray : 4.704594418369604e-05
# fk_nomtech_ULMMIN : 4.646071473653146e-05
# fk_port_étêté : 4.486780443973866e-05
# clc_secteur_Rue Galilée : 4.259148224195953e-05
# fk_nomtech_CUPSEM : 4.156060544360554e-05
# clc_secteur_Rond point Georges Pompidou : 4.1434618785741474e-05
# clc_secteur_Le million populaire : 4.054233990217807e-05
# clc_secteur_Groupe scolaire Camille Desmoulins : 4.05188604034237e-05
# clc_secteur_Rue Joule : 4.030777632740455e-05
# fk_nomtech_ACEPLAfai : 3.969520999943597e-05
# fk_nomtech_QUEROB : 3.932939990243947e-05
# clc_secteur_Rue du Général Raymond Appert : 3.914049941902481e-05
# fk_port_têtard relâché : 3.757497198612234e-05
# clc_secteur_Avenue de la Paix : 3.661408827607578e-05
# fk_nomtech_PRUSERfas : 3.621940256550061e-05
# clc_secteur_Chemin rural dit vieux chemin de Saint Quentin à Ribermont : 3.600791663636336e-05
# fk_nomtech_MALDOMcal : 3.549820734056204e-05
# clc_secteur_Rue Ampère : 3.5476925140540365e-05
# clc_secteur_Centre social Champagne - Artois : 3.5011458437520564e-05
# fk_nomtech_TILEUR : 3.453764676001652e-05
# clc_secteur_Rue Georges Cuvier : 3.432825518962459e-05
# clc_secteur_Parc animalier du Parc d'Isle : 3.3363082032916896e-05
# clc_secteur_Boulevard du Maréchal Juin : 3.268178808096696e-05
# fk_nomtech_LARDEC : 3.172414836608818e-05
# fk_nomtech_CERSIL : 3.083805138960827e-05
# clc_secteur_Square rue Fréreuse : 3.0024651945869746e-05
# clc_secteur_Ancienne ecole David et Maigret : 2.9112179795776786e-05
# clc_secteur_Communauté d'agglomération - Propriété privée - Tour y val : 2.884457252231186e-05
# fk_nomtech_POPEURrob : 2.8770614617747874e-05
# fk_nomtech_CUPARI : 2.868787380332344e-05
# fk_nomtech_ALNGLU : 2.7801380249770134e-05
# clc_secteur_Rue Jacques Blanchot : 2.7065262508099838e-05
# fk_nomtech_FAGSYLpen : 2.493987232159739e-05
# fk_nomtech_ABINOR : 2.4192612187622652e-05
# clc_secteur_Centre multi-sport Pierre Arnould : 2.3098167909603198e-05
# clc_secteur_Rue André Godin : 2.3031317664541804e-05
# clc_secteur_Place Cordier : 2.2935197917111234e-05
# clc_secteur_Rue Mariotte : 2.283137317499881e-05
# clc_secteur_Stade Cepy : 2.2599358333133187e-05
# clc_secteur_Rue Joliot Curie : 2.1830811465501367e-05
# fk_nomtech_MALTOR1 : 2.1572226169109048e-05
# clc_secteur_Rue Raoul Huguet : 2.0802431678556214e-05
# clc_secteur_Place Edouard Branly : 2.073498486017425e-05
# clc_secteur_Avenue Pierre Choquart : 1.961376676844037e-05
# clc_secteur_Ecole élémentaire Amédée Ozenfant : 1.8835085574380117e-05
# fk_nomtech_MAGKOB : 1.7970150396365174e-05
# clc_secteur_Rue Archimède : 1.7886251078817565e-05
# fk_nomtech_QUECOC : 1.7675366804028187e-05
# clc_secteur_Avenue Léo Lagrange : 1.7224602242507633e-05
# clc_secteur_Gymnase Bertrand Gamess : 1.6894172003224446e-05
# fk_nomtech_MAGSOUhea : 1.6755425541869457e-05
# fk_nomtech_TILPLA : 1.671413421092925e-05
# clc_secteur_Entrée de ville Avenue Pierre Choquart : 1.6113049622785867e-05
# clc_secteur_Cimetière de la Tombelle : 1.5746911479735917e-05
# clc_secteur_Entrée de ville rue de Paris : 1.5586592094017776e-05
# fk_nomtech_TILHEN : 1.5497270513767532e-05
# fk_nomtech_CHALAW : 1.543041313056768e-05
# fk_nomtech_SORARI : 1.5318731798399396e-05
# fk_nomtech_PRUSERpen : 1.5303432763859466e-05
# clc_secteur_Rue de la Chaussée Romaine : 1.5234141876235358e-05
# clc_secteur_Rue des Glacis : 1.509435168832962e-05
# clc_secteur_Rue d'Amiens prolongée : 1.4871017424595848e-05
# fk_nomtech_QUESHU : 1.4408745059725048e-05
# clc_secteur_Verger du théâtre de la manufacture : 1.3904127566256638e-05
# fk_nomtech_ACEPAL : 1.3739464762042987e-05
# clc_secteur_Rue d'Aboukir : 1.3657629896511757e-05
# fk_nomtech_AMELAM : 1.3503721401748349e-05
# fk_nomtech_FAGSYLdawgol : 1.3118899131355763e-05
# clc_secteur_Cimetière sud - chemin d'Harly : 1.2888291995685924e-05
# clc_secteur_Centre de formation Bachy : 1.2209760153054971e-05
# fk_nomtech_TAXBACfas : 1.1951821138170065e-05
# clc_secteur_Rue du Commandant Charcot : 1.1893990522251316e-05
# fk_nomtech_AILALT : 1.1787940758439446e-05
# fk_nomtech_PYRCOM : 1.1726845115351572e-05
# fk_nomtech_ACEPLAcol : 1.171781310445032e-05
# clc_secteur_Square Pierre Boulard : 1.1628412513076143e-05
# fk_nomtech_MALPEReve : 1.1373159898105544e-05
# fk_nomtech_ACERUB : 1.0964752398004569e-05
# clc_secteur_Rue Gaston Bonnier : 1.0505665032345355e-05
# clc_secteur_Boulevard Henri Martin : 1.024170102757251e-05
# fk_port_têtard : 9.772667330287303e-06
# clc_secteur_Quai Gayant : 9.646454433037721e-06
# clc_secteur_Gymnase Robert Schuman : 9.584901364007139e-06
# fk_nomtech_PINSYL : 9.34954745210696e-06
# clc_secteur_Rue du Cardinal Saliège : 9.334256486062138e-06
# clc_secteur_Boulevard Gambetta : 9.268152765453706e-06
# clc_secteur_Avenue Faidherbe : 9.219918180153436e-06
# fk_nomtech_SORARIlut : 9.16045731804617e-06
# clc_secteur_Square Gaston Massot : 8.900570097845996e-06
# fk_nomtech_PRU : 8.897281364559667e-06
# fk_nomtech_ALNSPA : 8.866738320967574e-06
# clc_secteur_Rue des Anciens Combattants en Afrique du Nord : 8.651204003864138e-06
# fk_nomtech_MALTOR : 8.475450739582802e-06
# clc_secteur_Rue Henri Farman : 8.296682766430724e-06
# fk_nomtech_SALCAP : 7.265448522493506e-06
# fk_nomtech_ABIGLA : 6.251633318519294e-06
# clc_secteur_Ecole maternelle Ernest Lavisse : 5.952675331914068e-06
# fk_nomtech_PRUCER : 5.691859008375553e-06
# clc_secteur_Avenue du Cimetière de La Tombelle : 5.557892926781031e-06
# fk_nomtech_MALgol : 5.5553290672842665e-06
# fk_nomtech_GLETRI : 5.399407693154123e-06
# fk_nomtech_BETPENyou : 5.291612869899063e-06
# fk_nomtech_QUECER : 5.249602000462924e-06
# clc_secteur_Groupe scolaire Xavier Aubryet : 5.1274558212349485e-06
# clc_secteur_Boulevard Victor Hugo : 4.929311411768503e-06
# fk_nomtech_ALNCOR : 4.894167376324452e-06
# clc_secteur_Rue Albert Calmette : 4.871933791432429e-06
# fk_nomtech_ACEPLApur : 4.841908868500249e-06
# clc_secteur_Rue de la Mayenne : 4.7896837536116526e-06
# clc_secteur_Rond Point Mc Donald : 4.456314623839114e-06
# fk_nomtech_CEDLIB : 4.4496129329957055e-06
# clc_secteur_Square de Kaiserlautern : 3.5690146881657004e-06
# fk_nomtech_CHANOO : 3.488611693196571e-06
# fk_nomtech_SAMNIG : 3.374884417679783e-06
# clc_secteur_Avenue de la République : 3.1611708669197015e-06
# clc_secteur_Maison de la Petite enfance : 3.0998461749693987e-06
# clc_secteur_Route de Chauny : 3.064933715711585e-06
# fk_nomtech_FRAPEN : 3.0200141700653683e-06
# fk_nomtech_CRAMON : 2.9423962258947427e-06
# clc_secteur_Square Quentin de la Tour : 2.7842790805166254e-06
# fk_nomtech_PRUAVI : 2.743314546770069e-06
# fk_nomtech_SORALB : 2.7366869378480104e-06
# clc_secteur_Avenue du Général de Gaulle : 2.734214415188118e-06
# fk_nomtech_MALCOM : 2.7116051062509137e-06
# fk_nomtech_GLETRIsun : 2.6792161931517285e-06
# clc_secteur_Rue Roland Garros : 2.5889990214143324e-06
# fk_nomtech_MALDOM : 2.4217002051387663e-06
# fk_nomtech_FRAPENcim : 2.418037412120695e-06
# clc_secteur_Parcelle CO0456 : 2.4030574651307574e-06
# clc_secteur_Place des Girondins : 2.385570858792656e-06
# clc_secteur_Rue Emilie et Raymond Pierret : 2.3779428410731256e-06
# clc_secteur_Boulevard de Verdun : 2.257594197242963e-06
# clc_secteur_Rue du Très Révérend Père Léon Jean Dehon : 2.179923690102527e-06
# clc_secteur_Rue de Touraine : 2.1781261996111464e-06
# clc_secteur_Boulevard du Docteur Schweitzer : 2.1291880204015953e-06
# clc_secteur_Parking Ecole Ferdinand Buisson : 2.0476482134431265e-06
# clc_secteur_Square Rocourt : 1.9052246673895032e-06
# fk_nomtech_SORTOR : 1.877831217232522e-06
# fk_nomtech_NOTANT : 1.873628102827537e-06
# fk_nomtech_MALCOMtra : 1.8726923765548535e-06
# clc_secteur_Rue Fournier : 1.6990706085863455e-06
# fk_nomtech_PRUMAAamb : 1.623400076296462e-06
# clc_secteur_Palais de Fervaques : 1.6173970695563628e-06
# fk_nomtech_PRULAU : 1.5926595186015523e-06
# clc_secteur_Rue Demoustier : 1.5745810887383685e-06
# clc_secteur_Verger du Parc d'Isle : 1.5306135186573263e-06
# clc_secteur_Ecole maternelle des Girondins : 1.526510951800673e-06
# fk_nomtech_MALPEN : 1.4984834193854354e-06
# fk_port_rideau : 1.390052327553517e-06
# clc_secteur_Ecole maternelle Robert Schuman : 1.3342279578342412e-06
# clc_quartier_ROUVROY : 1.2963483663103034e-06
# fk_nomtech_QUEPAL : 1.2624698314977332e-06
# fk_nomtech_QUEELL : 1.2213289348156152e-06
# fk_nomtech_ACEPSEatr : 1.2127321423616938e-06
# fk_nomtech_MALDOMbos : 1.1835667374973783e-06
# fk_nomtech_PSEMEN : 1.1121702306440922e-06
# clc_secteur_Ecole maternelle François Collery : 1.0375689328508255e-06
# clc_secteur_Local Espaces Verts Europe : 1.0236719154259463e-06
# clc_secteur_Rue Leon Lemire : 9.970300373374526e-07
# clc_secteur_Rue Georges Brassens : 9.637131542078065e-07
# fk_nomtech_CRYJAP : 9.584274634639083e-07
# clc_secteur_Rue Emile et Raymond Pierret prolongé : 9.504180572544197e-07
# clc_secteur_Cimetière Saint-Jean : 8.861256463956222e-07
# clc_secteur_Ecole primaire des Girondins : 8.621614696432177e-07
# fk_nomtech_MALDOMgra : 8.310682291171739e-07
# clc_secteur_Banque alimentaire : 8.215021783550173e-07
# fk_nomtech_FRAANG : 8.111858336464329e-07
# fk_nomtech_PINNIGlar : 7.9563850003482e-07
# fk_pied_Bac de plantation : 7.800358781552448e-07
# clc_secteur_Ecole maternelle des Patriotes : 7.543378110457181e-07
# fk_nomtech_PRUAVIbig : 7.426533908402713e-07
# clc_secteur_Entrée de ville RD 300 Rouvray : 7.373542118959969e-07
# clc_secteur_Eglise Jean XXIII : 6.952319268179149e-07
# clc_secteur_Rue Albert Thomas : 6.850849869356979e-07
# fk_nomtech_FAGSYLdawpur : 6.383682896388926e-07
# fk_nomtech_MAGGRA : 6.345862885772973e-07
# clc_secteur_Mairie annexe du Faubourg d'Isle : 5.995749153336221e-07
# clc_secteur_Avenue Aristide Briand : 5.773634776148082e-07
# fk_nomtech_CORAVE : 5.66566717995068e-07
# clc_secteur_Rue Emile Rousseau : 5.351504583881302e-07
# fk_nomtech_PARPER : 5.239549375383261e-07
# clc_secteur_Rue Louis Bréguet : 5.146513935286893e-07
# fk_nomtech_ABI : 4.612738994430373e-07
# clc_secteur_Rue de Phalsbourg : 4.414468219992701e-07
# fk_nomtech_ACECAP : 4.331671476159463e-07
# clc_secteur_Rue Jean Labouret : 4.318992073300014e-07
# fk_nomtech_BUXSEM : 4.281096877012974e-07
# fk_nomtech_CUPLEYvar : 4.1389276647298154e-07
# clc_secteur_La Boisselle : 4.0736590106264304e-07
# fk_nomtech_ACEPSEleo : 3.6247690644437244e-07
# fk_nomtech_FRAEXCpen : 3.4477723675754204e-07
# fk_nomtech_PRUDOMcha : 2.4767388461647164e-07
# clc_secteur_Square Raoul Huguet : 1.9818840255111881e-07
# fk_nomtech_GLETRIine : 1.905930281415232e-07
# clc_secteur_Rue Villebois Mareuil : 1.8627908257680578e-07
# clc_secteur_Rue de Vermand : 1.8318597097180424e-07
# clc_secteur_Rue du Maréchal Foch : 1.5380924203607826e-07
# fk_nomtech_PRUDOMrei : 1.3926219297057167e-07
# fk_nomtech_CEDATLgla : 1.3337384114920008e-07
# clc_secteur_Centre commercial Neuville : 1.3090070983950546e-07
# fk_nomtech_SOPJAPpen : 1.2632044344340325e-07
# fk_nomtech_JUNMEDpfi : 1.1791576849465012e-07
# clc_secteur_Rue d'Artois : 1.047696060004131e-07
# clc_secteur_Place Noël Regnier : 1.0288120596375502e-07
# fk_nomtech_SALALBche : 1.0152675910870717e-07
# clc_secteur_Boulevard Léon Blum : 9.627200507101438e-08
# clc_secteur_Rue de la Croix Saint-Claude : 9.434521765044931e-08
# clc_secteur_Square de la 2ème DB : 8.008535938538453e-08
# fk_nomtech_MALDOMbel : 7.73644670530825e-08
# fk_nomtech_ULMJAP : 7.548242023641248e-08
# clc_secteur_Groupe scolaire Alfred Clin : 7.167507701300562e-08
# fk_nomtech_METGLY : 6.635262776477297e-08
# clc_secteur_Rue de Tour-Y-Val : 5.219191673492553e-08
# clc_secteur_Parc des Champs-Elysées : logement de fonction : 5.0934754629566145e-08
# clc_secteur_Rond point Jean Bouin : 4.0801414149945043e-08
# fk_nomtech_THUPLIzeb : 3.6611923660034856e-08
# fk_nomtech_ACECAMele : 3.555076730788647e-08
# fk_nomtech_PRUSERama : 3.400956735160558e-08
# fk_nomtech_QUERUB : 3.035446926310989e-08
# fk_nomtech_MALTSC : 2.887533607887891e-08
# fk_nomtech_MALDOMrei : 2.878606000084031e-08
# clc_secteur_Ruelle Carlier : 2.662180181487434e-08
# clc_secteur_Rue D'Ostende : 2.6273008117752726e-08
# fk_nomtech_QUEBIC : 2.336986577431899e-08
# clc_secteur_Rue du Général Leclerc : 1.849616016510364e-08
# fk_nomtech_PINWAL : 1.766325978993317e-08
# clc_secteur_Place Roterham : 1.6249915235373564e-08
# fk_nomtech_CEDDEO : 1.6119503436227585e-08
# clc_secteur_Rue de la Convention : 1.1851883428503918e-08
# fk_nomtech_ALNGLUimp : 1.0352922927970378e-08
# fk_nomtech_CORKOU : 9.148095605750264e-09
# fk_nomtech_PRUDOMrei1 : 8.671324074781053e-09
# clc_secteur_Rue d'Artois Terrain de jeu : 7.671925632993712e-09
# fk_nomtech_MALTORbro : 5.072263686633326e-09
# fk_nomtech_PRUCERbig1 : 4.0695080806415e-09
# fk_nomtech_ELAANG : 2.4877854050309625e-09
# fk_nomtech_MAGSOU : 1.992315517952636e-09
# fk_nomtech_ROBPSEfri : 1.5575116954156203e-09
# clc_secteur_Résidence OPAC rue du Docteur Cordier : 1.2746062730832404e-09
# fk_nomtech_TAXDIS : 1.1379639557199515e-09
# fk_nomtech_ILEAQU : 5.952713364177257e-10
# clc_secteur_square des marronniers  : 5.888820193822793e-10
# fk_nomtech_PRUDOMrei3 : 0.0
# fk_nomtech_ULMRESreb : 0.0
# fk_nomtech_PRUDOMrei2 : 0.0
# clc_secteur_Boulevard Richelieu : 0.0
# fk_nomtech_PRUPERnuc : 0.0
# fk_nomtech_ULMRESsap : 0.0
# fk_nomtech_PRUCERbig : 0.0
# fk_nomtech_ULMRES : 0.0
# clc_secteur_Square des Héros du 2 Septembre 1944 : 0.0
# fk_nomtech_QUEILE : 0.0
# clc_secteur_Salle Charles de Foucauld : 0.0
# fk_nomtech_PRUDOMals : 0.0
# fk_nomtech_PRUSUBaut : 0.0
# fk_nomtech_PRUDOMmir : 0.0
# clc_secteur_Square rue du Blanc Mont : 0.0
# fk_nomtech_PYRCOMcon : 0.0
# clc_secteur_Accueil de loisirs Kergomard : 0.0
# fk_nomtech_PYRCOMdoy : 0.0
# fk_nomtech_QUEPET : 0.0
# fk_nomtech_PRUCERbig2 : 0.0
# clc_secteur_Salle Vermand Fayet : 0.0
# fk_nomtech_QUECAS : 0.0
# clc_secteur_Salle Paringault : 0.0
# fk_nomtech_PRUCERcoe : 0.0
# fk_nomtech_PRUDOMmon : 0.0
# fk_nomtech_QUEMAC : 0.0
# fk_nomtech_ALBJUL : 0.0
# fk_nomtech_MALDOMcox : 0.0
# clc_secteur_rue Hertz : 0.0
# clc_secteur_Rue Alexandre Ribot : 0.0
# clc_secteur_Place Danton : 0.0
# fk_nomtech_FAGSYLfas : 0.0
# clc_secteur_Place Georges Bizet : 0.0
# fk_nomtech_ABINUM : 0.0
# clc_secteur_Place du Docteur Petithomme : 0.0
# fk_nomtech_CYDVULbou : 0.0
# fk_nomtech_TAMGAL : 0.0
# fk_nomtech_ACE : 0.0
# fk_nomtech_CUPfas : 0.0
# fk_nomtech_ACECAMred : 0.0
# fk_nomtech_PRUAVImar : 0.0
# clc_secteur_Rue Pontoile : 0.0
# fk_nomtech_ACENEGvar : 0.0
# clc_secteur_Rue Emile Zola : 0.0
# fk_nomtech_CEDATLpen : 0.0
# fk_nomtech_BETUTIjac : 0.0
# fk_nomtech_BETPAP : 0.0
# clc_secteur_Rue Henri Dunant : 0.0
# clc_secteur_Rue Hélène Boucher : 0.0
# fk_nomtech_RHUTYP : 0.0
# clc_secteur_Place Crommelin : 0.0
# clc_secteur_Place Carnot : 0.0
# fk_nomtech_ABILASari : 0.0
# clc_secteur_Rue de Ham : 0.0
# fk_nomtech_PRUAVIbea : 0.0
# clc_secteur_Rue du Docteur Cordier : 0.0
# fk_nomtech_QUEROBfas : 0.0
# clc_secteur_Chemin de Lehaucourt : 0.0
# clc_secteur_Rue des Vieux ménages : 0.0
# fk_nomtech_MALred : 0.0
# fk_nomtech_MALTRI : 0.0
# clc_secteur_Rue des Corbeaux : 0.0
# clc_secteur_Rue des Arts : 0.0
# fk_nomtech_MALDOMmel : 0.0
# fk_nomtech_ALBJULcho : 0.0
# fk_nomtech_MALDOMast : 0.0
# fk_nomtech_MALCOMgol : 0.0
# fk_nomtech_MALBAC : 0.0
# fk_nomtech_LAGIND : 0.0
# fk_nomtech_KOEPAN : 0.0
# clc_secteur_Rue de Tourcoing : 0.0
# fk_nomtech_ABICON : 0.0
# clc_secteur_Rue de Normandie : 0.0
# fk_nomtech_FRAAME : 0.0

# %%
# Utiliser les caractéristiques les plus importantes pour entraîner un nouveau modèle
X_train_selected = X_train_smote[:, indices[:20]]
best_clf.fit(X_train_selected, y_train_smote)
X_test_selected = X_test[:, indices[:20]]


# Prédiction
y_pred = best_clf.predict(X_test_selected)


# Évaluation du modèle
print("\nAccuracy : ", accuracy_score(y_test, y_pred))
print("\nClassification Report :")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix :")
print(confusion_matrix(y_test, y_pred, normalize='true'))
print("\naccuracy Score :")
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9802069275753487
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2181
#            1       0.46      0.26      0.33        42
#
#     accuracy                           0.98      2223
#    macro avg       0.72      0.63      0.66      2223
# weighted avg       0.98      0.98      0.98      2223
#
#
# Confusion Matrix :
# [[0.99403943 0.00596057]
#  [0.73809524 0.26190476]]
#
# accuracy Score :
# 0.9802069275753487
